# %%
import numpy as np
import matplotlib.pyplot as plt

lypplt = np.loadtxt('array.txt')

# %%
fig = plt.figure(figsize = (10,5)); 

plt.plot(lypplt)

plt.grid()

plt.ylabel('lambda')
plt.title('Lyapunov exponent')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Lyapunov exponent')
